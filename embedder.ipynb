# %%
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv

load_dotenv()

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

#테스트
test = embeddings.embed_query("국민연금공단 예산이 얼마야?")
print(f"임베딩 벡터 차원: {len(test)}")
# Out:
# 임베딩 벡터 차원: 1536
